# %%
import matplotlib.pyplot as plt

# %%
plt.bar(list('ABC'),[10,0,20])
# Out:
# <BarContainer object of 3 artists>

# %%
sequences = ['ACGT','GTAC', 'ABCDE']
scores = [[1,2,10,0],[1,2,10,0],[1,2,10,1,11]]
fig, axes = plt.subplots(len(scores),1)

fig.suptitle('This is a somewhat long figure title', fontsize=16)

for ax, seq, score in zip(axes, sequences, scores):
    ax.bar(list(seq), score)
    ax.set_xlabel('Sequence')
    ax.set_ylabel('scores')
    ax.set_title('WMM Scores', share = True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-5ecb30613653> in <module>
#       9     ax.set_xlabel('Sequence')
#      10     ax.set_ylabel('scores')
# ---> 11     ax.set_title('WMM Scores', share = True)
#
# ~\AppData\Local\Continuum\miniconda3\envs\aml\lib\site-packages\matplotlib\axes\_axes.py in set_title(self, label, fontdict, loc, pad, **kwargs)
#     211         if fontdict is not None:
#     212             title.update(fontdict)
# --> 213         title.update(kwargs)
#     214         return title
#     215
#
# ~\AppData\Local\Continuum\miniconda3\envs\aml\lib\site-packages\matplotlib\text.py in update(self, kwargs)
#     175         sentinel = object()  # bbox can be None, so use another sentinel.
#     176         bbox = kwargs.pop("bbox", sentinel)
# --> 177         super().update(kwargs)
#     178         if bbox is not sentinel:
#     179             self.set_bbox(bbox)
#
# ~\AppData\Local\Continuum\miniconda3\envs\aml\lib\site-packages\matplotlib\artist.py in update(self, props)
#     972
#     973         with cbook._setattr_cm(self, eventson=False):
# --> 974             ret = [_update_property(self, k, v) for k, v in props.items()]
#     975
#     976         if len(ret):
#
# ~\AppData\Local\Continuum\miniconda3\envs\aml\lib\site-packages\matplotlib\artist.py in <listcomp>(.0)
#     972
#     973         with cbook._setattr_cm(self, eventson=False):
# --> 974             ret = [_update_property(self, k, v) for k, v in props.items()]
#     975
#     976         if len(ret):
#
# ~\AppData\Local\Continuum\miniconda3\envs\aml\lib\site-packages\matplotlib\artist.py in _update_property(self, k, v)
#     968                 if not callable(func):
#     969                     raise AttributeError('{!r} object has no property {!r}'
# --> 970                                          .format(type(self).__name__, k))
#     971                 return func(v)
#     972
#
# AttributeError: 'Text' object has no property 'share'

# %% [markdown]
# Let c(j) be the count of the number of test sequences whose highest WMM score (leftmost highest, if ties) occurred at position j . Plot this histogram. Additionally, calculate and print m = arg max { c(j) | 1 ≤ j ≤ 113-k+1 }. I.e., m is the most common location of the best motif hit in each sequence

# %%
import numpy as np
plt.style.use('ggplot')
max_len = max([len(seq) for seq in sequences])
c = np.zeros(max_len, dtype = int)
for i,score in enumerate(scores):
    j = np.argmax(score)
    c[j] += 1
plt.bar(range(1,max_len+1),c)
plt.title('High scores counts per position')
plt.xlabel('position')
plt.ylabel('count')
print(np.argmax(c)+1)
# Out:
# 3
